# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('spotify_reviews.csv')

# %%
data
# Out:
#                                    reviewId                      userName  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58                     Rajib Das
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f         Mihaela Claudia Neagu
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e               JONATHAN GRACIA
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382                    Cam Rempel
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578  Your clowness (Her Clowness)
# ...                                     ...                           ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95                 Marlena Scott
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e                 A Google user
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3                Supriya Deepak
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383                 A Google user
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df                  lewis matley
#
#                                                  content  score  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84165 entries, 0 to 84164
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              84165 non-null  object
#  1   userName              84161 non-null  object
#  2   content               84165 non-null  object
#  3   score                 84165 non-null  int64
#  4   thumbsUpCount         84165 non-null  int64
#  5   reviewCreatedVersion  78397 non-null  object
#  6   at                    84165 non-null  object
#  7   appVersion            78397 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 5.1+ MB

# %%
data = data.drop(columns='userName')
data
# Out:
#                                    reviewId  \
# 0      437314fe-1b1d-4352-abea-12fec30fce58
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578
# ...                                     ...
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e
# 84162  33317821-01e1-4207-964f-ae8109a0d6b3
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df
#
#                                                  content  score  \
# 0                                              It's good      4
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# ...

# %%
data = data[~(data['reviewCreatedVersion'] != data['appVersion'])]
data = data.drop(columns='reviewCreatedVersion')
data
# Out:
#                                    reviewId  \
# 1      4933ad2c-c70a-4a84-957d-d405439b2e0f
# 2      1ab275fb-59bf-42c7-88ef-b85901f0445e
# 3      b38406eb-7b11-4ceb-a45c-d7f28fb5d382
# 4      7be7999d-4cb6-47b9-8414-d7bdaa9df578
# 5      1c260703-26fb-404c-b7b0-dcbd2f93a415
# ...                                     ...
# 84159  fe973ecc-c675-41a7-ba2c-e1cb9e5cd7a2
# 84160  b41ccea7-2805-458a-bd70-547ff07ddb95
# 84161  456cbd4f-d9b5-4d7b-8a7d-caab7593431e
# 84163  98acdcd9-a1e8-4d49-9fc8-1aee84d14383
# 84164  4263fcac-7aac-464c-b007-a7a25797b9df
#
#                                                  content  score  \
# 1      I love this app so much, I've been using Spoti...      5
# 2                                                Perfect      5
# 3      Best all around music streaming app I have use...      5
# 4      Are y'all fr gatekeeping the play button on so...      1
# 5                                               Loved it      5
# ...

# %%
#data['at'] = pd.to_datetime(data['at'],format='%y/%m/%d')
#data['year'] = data['at'].dt.year
#data['month'] = data['at'].dt.month
#data['day'] = data['at'].dt.day
#data['hour'] = data['at'].dt.hour
#data['minute'] = data['at'].dt.minute
#data = data.drop(columns='at')

# %%
data['at'] = pd.to_datetime(data['at'])
data['at'].value_counts()
# Out:
# at
# 2024-05-04 05:12:58    2
# 2023-11-27 10:17:03    2
# 2024-05-09 15:13:15    2
# 2024-05-06 11:44:52    2
# 2022-11-16 11:32:03    2
#                       ..
# 2018-09-19 21:25:57    1
# 2021-06-07 23:18:22    1
# 2021-02-22 04:47:28    1
# 2022-04-12 16:13:40    1
# 2020-06-13 03:27:52    1
# Name: count, Length: 78326, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78397 entries, 1 to 84164
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       78397 non-null  object
#  1   content        78397 non-null  object
#  2   score          78397 non-null  int64
#  3   thumbsUpCount  78397 non-null  int64
#  4   at             78397 non-null  datetime64[ns]
#  5   appVersion     78397 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 4.2+ MB
