# %% [markdown]
# # Importe de librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/jpospinalo/MachineLearning/main/Linear%20Regression/advertising2.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper    Sales
# 0  164.5   20.9       47.4  17.5000
# 1    NaN    NaN        NaN  15.1305
# 2   75.5   10.8        6.0  11.9000
# 3  237.4    5.1       23.5  17.5000
# 4   97.5    7.6        7.2  13.7000

# %%
df.shape
# Out:
# (208, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      208 non-null    float64
# dtypes: float64(4)
# memory usage: 6.6 KB

# %%
df['Sales'].unique()
# Out:
# array(['17.5', '15.130500000000003', '11.9', '13.7', '7.6', '11.8',
#        '10.1', '20.7', '19.0', '22.2', '7.2', '4.8', '20.5', '15.2',
#        '9.7', '17.0', '20.0', '10.3', '10.8', '16.7', '11.5', '12.6',
#        '12.0', '5.5', '10.4', '18.4', '17.6', '15.0', '12.2', '24.7',
#        '5.3', '19.8', '17.1', '8.1', '14.0', '27.0', '19.2', '9.2',
#        '15.130500000000001', '18.0', '13.3', '22.3', '17.9', '16.5',
#        '25.4', '11.0', '24.2', '10.5', '10.6', '7.3', '6.9', '19.9',
#        '21.2', '8.5', '17.2', '14.8', '10.9', '20.6', '20.8', '8.4',
#        '25.5', '3.2', '21.7', '1.6', '21.4', '16.9', '16.8', '17.8',
#        '11.6', '12.9', '13.2', '12.4', '24.4', '16.1', '8.7', '10.7',
#        '19.6', '7.0', '15.9', '18.9', '22.4', '11.3', '17.3', '9.4',
#        '20.9', '20.2', '19.4', '13.6', '5.7', '16.4', '21.8', '18.2',
#        '13.4', '15.6', '23.2', '22.6', '20.1', '21.5', '9.5', '14.7',
#        '17.4', '12.5', '19.7', '5.6', '26.2', '12.3', '15.5', '15.3',
# ...

# %%
df['Sales'] = df['Sales'].str.replace(',', '.')

# %%
df['Sales'] = df['Sales'].astype(float)

# %%
df.isnull().sum()
# Out:
# TV           8
# Radio        8
# Newspaper    8
# Sales        0
# dtype: int64

# %%
df[df['Newspaper'].isnull()]
# Out:
#      TV  Radio  Newspaper    Sales
# 1   NaN    NaN        NaN  15.1305
# 7   NaN    NaN        NaN  15.1305
# 37  NaN    NaN        NaN  15.1305
# 47  NaN    NaN        NaN  15.1305
# 55  NaN    NaN        NaN  15.1305
# 85  NaN    NaN        NaN  15.1305
# 109 NaN    NaN        NaN  15.1305
# 146 NaN    NaN        NaN  15.1305

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.pairplot(data=df)

# %% [markdown]
# # Modelamiento

# %%
# Generó los conjuntos de entrenamiento y prueba
from sklearn.model_selection import train_test_split

train, test =train_test_split(df, test_size=0.2, random_state=45, shuffle=True)
